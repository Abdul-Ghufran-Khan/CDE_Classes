# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv(r"D:\Anaconda\cde-b3\exploratory-data-analysis-eda\Day 3 (DataFrames & Aggregating Data)\dataset\titanic.csv",index_col=0)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
titanic["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
titanic.Age.median()
# Out:
# 28.0

# %%
titanic.Age.min()
# Out:
# 0.42

# %%
titanic.Age.max()
# Out:
# 80.0

# %%
titanic.Age.var()
# Out:
# 211.0191247463081

# %%
titanic.Age.sum()
# Out:
# np.float64(21205.17)

# %%
titanic["Age"].std()
# Out:
# 14.526497332334044

# %% [markdown]
# ### Agg() method

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
def pct30(col):return col.quantile(0.3)

# %%
titanic["Age"].agg(pct30)
# Out:
# np.float64(22.0)

# %%
titanic["Fare"].agg(pct30)
# Out:
# np.float64(8.05)

# %%
titanic["Age"].agg(lambda col:col.quantile(0.3))
# Out:
# np.float64(22.0)

# %%
titanic["Age"].agg(lambda col:col.quantile(0.3))
# Out:
# np.float64(22.0)

# %%
titanic[["Age","Fare"]].agg(lambda col:col.quantile(0.3))
# Out:
# Age     22.00
# Fare     8.05
# dtype: float64

# %% [markdown]
# ### Cumulative statistics

# %%
pd.DataFrame(titanic["Age"].cumsum()).head(5)
# Out:
#                Age
# PassengerId
# 1             22.0
# 2             60.0
# 3             86.0
# 4            121.0
# 5            156.0

# %%
pd.DataFrame(titanic["Age"].cummin()).head(5)
# Out:
#               Age
# PassengerId
# 1            22.0
# 2            22.0
# 3            22.0
# 4            22.0
# 5            22.0

# %%
pd.DataFrame(titanic["Age"].cummax()).head(5)
# Out:
#               Age
# PassengerId
# 1            22.0
# 2            38.0
# 3            38.0
# 4            38.0
# 5            38.0

# %%
titanic.drop_duplicates(subset="Pclass")
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C
# 10               1      0     237736  30.0708   NaN        C

# %%
titanic.drop_duplicates(subset="Age")
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 6                   0       3
# ...               ...     ...
# 756                 1       2
# 768                 0       3
# 804                 1       3
# 844                 0       3
# 852                 0       3
#
#                                                           Name     Sex    Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.00
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00
# 3                                       Heikkinen, Miss. Laina  female  26.00
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00
# 6                                             Moran, Mr. James    male    NaN
# ...                                                        ...     ...    ...
# 756                                  Hamalainen, Master. Viljo    male   0.67
# 768                                         Mangan, Miss. Mary  female  30.50
# 804                            Thomas, Master. Assad Alexander    male   0.42
# 844                                 Lemberopolous, Mr. Peter L    male  34.50
# 852                                        Svensson, Mr. Johan    male  74.00
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 6                0      0            330877   8.4583   NaN        Q
# ...            ...    ...               ...      ...   ...      ...
# 756              1      1            250649  14.5000   NaN        S
# 768              0      0            364850   7.7500   NaN        Q
# 804              0      1              2625   8.5167   NaN        C
# 844              0      0              2683   6.4375   NaN        C
# 852              0      0            347060   7.7750   NaN        S
#
# [89 rows x 11 columns]

# %%
titanic.drop_duplicates(subset="Sex")
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
titanic.drop_duplicates(subset=["Age","SibSp"])
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 820                 0       3
# 832                 1       2
# 844                 0       3
# 852                 0       3
# 861                 0       3
#
#                                                           Name     Sex    Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.00
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00
# 3                                       Heikkinen, Miss. Laina  female  26.00
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00
# 5                                     Allen, Mr. William Henry    male  35.00
# ...                                                        ...     ...    ...
# 820                               Skoog, Master. Karl Thorsten    male  10.00
# 832                            Richards, Master. George Sibley    male   0.83
# 844                                 Lemberopolous, Mr. Peter L    male  34.50
# 852                                        Svensson, Mr. Johan    male  74.00
# 861                                    Hansen, Mr. Claus Peter    male  41.00
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 820              3      2            347088  27.9000   NaN        S
# 832              1      1             29106  18.7500   NaN        S
# 844              0      0              2683   6.4375   NaN        C
# 852              0      0            347060   7.7750   NaN        S
# 861              2      0            350026  14.1083   NaN        S
#
# [190 rows x 11 columns]

# %%
pd.DataFrame(titanic["Age"].value_counts(sort=False))
# Out:
#        count
# Age
# 22.00     27
# 38.00     11
# 26.00     18
# 35.00     18
# 54.00      8
# ...      ...
# 0.67       1
# 30.50      2
# 0.42       1
# 34.50      1
# 74.00      1
#
# [88 rows x 1 columns]

# %%
pd.DataFrame(titanic["Age"].value_counts(normalize=True))
# Out:
#        proportion
# Age
# 24.00    0.042017
# 22.00    0.037815
# 18.00    0.036415
# 28.00    0.035014
# 30.00    0.035014
# ...           ...
# 24.50    0.001401
# 0.67     0.001401
# 0.42     0.001401
# 34.50    0.001401
# 74.00    0.001401
#
# [88 rows x 1 columns]

# %% [markdown]
# ### Grouping Summary

# %%
titanic[titanic["Sex"]=="male"]["Age"].mean()
# Out:
# np.float64(30.72664459161148)

# %%
titanic[titanic["Sex"]=="female"]["Age"].mean()
# Out:
# np.float64(27.915708812260537)

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
pd.DataFrame(titanic.groupby("Sex")["Age"].mean())
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby(["Survived","Sex"])["Age"].count()
# Out:
# Survived  Sex
# 0         female     64
#           male      360
# 1         female    197
#           male       93
# Name: Age, dtype: int64

# %%
pd.DataFrame(titanic.groupby(["Survived","Sex"])["Age"].count())
# Out:
#                  Age
# Survived Sex
# 0        female   64
#          male    360
# 1        female  197
#          male     93

# %%
titanic.groupby("Sex")["Age"].agg(["count","min","max"])
# Out:
#         count   min   max
# Sex
# female    261  0.75  63.0
# male      453  0.42  80.0

# %%
titanic.groupby(["Survived","Sex"])["Age"].agg(["count","min","max"])
# Out:
#                  count   min   max
# Survived Sex
# 0        female     64  2.00  57.0
#          male      360  1.00  74.0
# 1        female    197  0.75  63.0
#          male       93  0.42  80.0

# %%
titanic.groupby(["Sex"])["Age"].agg(["count","min","max"])
# Out:
#         count   min   max
# Sex
# female    261  0.75  63.0
# male      453  0.42  80.0

# %%
titanic.groupby(["Survived","Sex"])[["Age","SibSp"]].mean()
# Out:
#                        Age     SibSp
# Survived Sex
# 0        female  25.046875  1.209877
#          male    31.618056  0.440171
# 1        female  28.847716  0.515021
#          male    27.276022  0.385321

# %%
titanic.groupby(["Survived","Sex"])[["Age","SibSp"]].min()
# Out:
#                   Age  SibSp
# Survived Sex
# 0        female  2.00      0
#          male    1.00      0
# 1        female  0.75      0
#          male    0.42      0

# %%
titanic.groupby(["Survived","Sex"])[["Age","SibSp"]].max()
# Out:
#                   Age  SibSp
# Survived Sex
# 0        female  57.0      8
#          male    74.0      8
# 1        female  63.0      4
#          male    80.0      4

# %%
titanic.groupby(["Survived","Sex"])[["Age","SibSp"]].agg(["count","min","max"])
# Out:
#                   Age             SibSp
#                 count   min   max count min max
# Survived Sex
# 0        female    64  2.00  57.0    81   0   8
#          male     360  1.00  74.0   468   0   8
# 1        female   197  0.75  63.0   233   0   4
#          male      93  0.42  80.0   109   0   4

# %% [markdown]
# ### Pivots table

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic.pivot_table(values="Age",index="Sex")
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.pivot_table(values="Age",index="Sex",aggfunc="count")
# Out:
#         Age
# Sex
# female  261
# male    453

# %%
titanic.pivot_table(values="Age",index="Sex",aggfunc="mean")
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
import scipy
titanic.pivot_table(values="Age",index="Sex",aggfunc=scipy.stats.mode)
# Out:
#                Age
# Sex
# female   (nan, 53)
# male    (nan, 124)

# %%
titanic.pivot_table(values="Age",index="Sex",columns = "Survived")
# Out:
# Survived          0          1
# Sex
# female    25.046875  28.847716
# male      31.618056  27.276022

# %%
titanic.pivot_table(values="Age",index="Sex",columns = "Survived",fill_value=0,margins=True)
# Out:
# Survived          0          1        All
# Sex
# female    25.046875  28.847716  27.915709
# male      31.618056  27.276022  30.726645
# All       30.626179  28.343690  29.699118

# %%
titanic.pivot_table(values="Age",index="Sex",columns = "Survived",fill_value=0,margins=True, margins_name="mean")
# Out:
# Survived          0          1       mean
# Sex
# female    25.046875  28.847716  27.915709
# male      31.618056  27.276022  30.726645
# mean      30.626179  28.343690  29.699118
